# %% [markdown]
# ###### A cloth manufacturing company is interested to know about the segment or attributes causes high sale. Approach - A decision tree can be built with target variable Sale (we will first convert it in categorical variable) & all other variable will be independent in the analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.tree import DecisionTreeClassifier

# %%
df=pd.read_csv(r'C:\Users\shree\3D Objects\Assignment 14\Company_Data.csv')
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
df.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# max    191.000000   80.000000   18.000000

# %%
df.isna().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
df.hist()
plt.tight_layout()

# %%
df.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
#
#                   Age  Education
# Sales       -0.231815  -0.051955
# CompPrice   -0.100239   0.025197
# Income      -0.004670  -0.056855
# Advertising -0.004557  -0.033594
# Population  -0.042663  -0.106378
# Price       -0.102177   0.011747
# Age          1.000000   0.006488
# Education    0.006488   1.000000

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
oe=OrdinalEncoder()
col_sel=df.select_dtypes(include='object').columns
df[col_sel]=oe.fit_transform(df[col_sel])
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120        0.0   42
# 1    11.22        111      48           16         260     83        1.0   65
# 2    10.06        113      35           10         269     80        2.0   59
# 3     7.40        117     100            4         466     97        2.0   55
# 4     4.15        141      64            3         340    128        0.0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128        1.0   33
# 396   6.14        139      23            3          37    120        2.0   55
# 397   7.41        162      26           12         368    159        2.0   40
# 398   5.94        100      79            7         284     95        0.0   50
# 399   9.71        134      37            0          27    120        1.0   49
#
#      Education  Urban   US
# 0           17    1.0  1.0
# 1           10    1.0  1.0
# 2           12    1.0  1.0
# 3           14    1.0  1.0
# 4           13    1.0  0.0
# ..         ...    ...  ...
# 395         14    1.0  1.0
# 396         11    0.0  1.0
# 397         18    1.0  1.0
# 398         12    1.0  1.0
# 399         16    1.0  1.0
#
# [400 rows x 11 columns]

# %%
# oe=OrdinalEncoder()
# col_sel=df.select_dtypes(include='object')
# oe_col=oe.fit_transform(col_sel)
# oe_col=pd.DataFrame(oe_col)
# oe_col

# %%
# df['ShelveLoc']=oe_col[0]
# df['Urban']=oe_col[1]
# df['US']=oe_col[2]
# df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    float64
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    float64
#  10  US           400 non-null    float64
# dtypes: float64(4), int64(7)
# memory usage: 34.5 KB

# %% [markdown]
# ###### Target column is sale according to problem statem(we will first convert it in categorical variable)

# %%
df.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# ShelveLoc    0.157470   0.023350 -0.067678     0.008544   -0.044772  0.014633
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
# Urban       -0.015419   0.066594  0.037967     0.042035   -0.052025  0.047016
# US           0.177093   0.016869  0.089601     0.684460    0.060564  0.057861
#
#              ShelveLoc       Age  Education     Urban        US
# Sales         0.157470 -0.231815  -0.051955 -0.015419  0.177093
# CompPrice     0.023350 -0.100239   0.025197  0.066594  0.016869
# Income       -0.067678 -0.004670  -0.056855  0.037967  0.089601
# Advertising   0.008544 -0.004557  -0.033594  0.042035  0.684460
# Population   -0.044772 -0.042663  -0.106378 -0.052025  0.060564
# Price         0.014633 -0.102177   0.011747  0.047016  0.057861
# ShelveLoc     1.000000  0.056488   0.001492 -0.063978 -0.039760
# Age           0.056488  1.000000   0.006488  0.028479  0.008652
# Education     0.001492  0.006488   1.000000 -0.033094 -0.078250
# Urban        -0.063978  0.028479  -0.033094  1.000000  0.047085
# US           -0.039760  0.008652  -0.078250  0.047085  1.000000

# %%
plt.rcParams['figure.figsize']=(10,5)
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df["sales"]="Bad"
df.loc[df["Sales"]>7.49,"sales"]="Good"
df.drop(["Sales"],axis=1,inplace=True)

# %%
df
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120        0.0   42
# 1          111      48           16         260     83        1.0   65
# 2          113      35           10         269     80        2.0   59
# 3          117     100            4         466     97        2.0   55
# 4          141      64            3         340    128        0.0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128        1.0   33
# 396        139      23            3          37    120        2.0   55
# 397        162      26           12         368    159        2.0   40
# 398        100      79            7         284     95        0.0   50
# 399        134      37            0          27    120        1.0   49
#
#      Education  Urban   US sales
# 0           17    1.0  1.0  Good
# 1           10    1.0  1.0  Good
# 2           12    1.0  1.0  Good
# 3           14    1.0  1.0   Bad
# 4           13    1.0  0.0   Bad
# ..         ...    ...  ...   ...
# 395         14    1.0  1.0  Good
# 396         11    0.0  1.0   Bad
# 397         18    1.0  1.0   Bad
# 398         12    1.0  1.0   Bad
# 399         16    1.0  1.0  Good
#
# [400 rows x 11 columns]

# %%
x=df.iloc[:,0:10]
y=df.loc[:,'sales']
x
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120        0.0   42
# 1          111      48           16         260     83        1.0   65
# 2          113      35           10         269     80        2.0   59
# 3          117     100            4         466     97        2.0   55
# 4          141      64            3         340    128        0.0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128        1.0   33
# 396        139      23            3          37    120        2.0   55
# 397        162      26           12         368    159        2.0   40
# 398        100      79            7         284     95        0.0   50
# 399        134      37            0          27    120        1.0   49
#
#      Education  Urban   US
# 0           17    1.0  1.0
# 1           10    1.0  1.0
# 2           12    1.0  1.0
# 3           14    1.0  1.0
# 4           13    1.0  0.0
# ..         ...    ...  ...
# 395         14    1.0  1.0
# 396         11    0.0  1.0
# 397         18    1.0  1.0
# 398         12    1.0  1.0
# 399         16    1.0  1.0
#
# [400 rows x 10 columns]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.7,random_state=2)

# %%
dt=DecisionTreeClassifier()
dt.fit(xtrain,ytrain)
ypred=dt.predict(xtest)

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          Bad       0.73      0.73      0.73        64
#         Good       0.70      0.70      0.70        56
#
#     accuracy                           0.72       120
#    macro avg       0.72      0.72      0.72       120
# weighted avg       0.72      0.72      0.72       120

# %%
confusion_matrix(ytest,ypred)
# Out:
# array([[47, 17],
#        [17, 39]], dtype=int64)

# %%
dt.score(xtrain,ytrain),dt.score(xtest,ytest)
# Out:
# (1.0, 0.7166666666666667)

# %%
dt.feature_importances_
# Out:
# array([0.12349987, 0.07043832, 0.11052199, 0.13146808, 0.31588118,
#        0.05683433, 0.16560228, 0.01503473, 0.        , 0.01071921])

# %%
pd.DataFrame({'features':xtrain.columns,
              'IG':dt.feature_importances_
             }).sort_values(by='IG',ascending=False)
# Out:
#       features        IG
# 4        Price  0.315881
# 6          Age  0.165602
# 3   Population  0.131468
# 0    CompPrice  0.123500
# 2  Advertising  0.110522
# 1       Income  0.070438
# 5    ShelveLoc  0.056834
# 7    Education  0.015035
# 9           US  0.010719
# 8        Urban  0.000000

# %% [markdown]
# ### Hyperparameter

# %%
params = {
    'criterion' : ['gini','entropy'],
    'splitter' : ['best','random'],
    'max_depth' : [2,3,4,6,9,12,16],
    'min_samples_split':[2,4,5,6,8,10]
    }

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(DecisionTreeClassifier(), param_grid=params, verbose=-1)

# %%
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 6, 9, 12, 16],
#                          'min_samples_split': [2, 4, 5, 6, 8, 10],
#                          'splitter': ['best', 'random']},
#              verbose=-1)

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 16,
#  'min_samples_split': 5,
#  'splitter': 'random'}

# %%
dt1=DecisionTreeClassifier(criterion='entropy',max_depth=9,splitter='random',min_samples_split=8)

# %%
dt1.fit(xtrain,ytrain)
ypred=dt1.predict(xtest)

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          Bad       0.71      0.69      0.70        64
#         Good       0.66      0.68      0.67        56
#
#     accuracy                           0.68       120
#    macro avg       0.68      0.68      0.68       120
# weighted avg       0.68      0.68      0.68       120

# %%
dt1.score(xtrain,ytrain),dt1.score(xtest,ytest)
# Out:
# (0.8678571428571429, 0.6833333333333333)

# %%
dt1.feature_importances_
# Out:
# array([0.05565782, 0.02800722, 0.13513875, 0.06951827, 0.27518006,
#        0.23704425, 0.08884538, 0.03103623, 0.0444778 , 0.03509421])

# %%
pd.DataFrame({'features':xtrain.columns,
              'IG':dt1.feature_importances_
             }).sort_values(by='IG',ascending=False)
# Out:
#       features        IG
# 4        Price  0.275180
# 5    ShelveLoc  0.237044
# 2  Advertising  0.135139
# 6          Age  0.088845
# 3   Population  0.069518
# 0    CompPrice  0.055658
# 8        Urban  0.044478
# 9           US  0.035094
# 7    Education  0.031036
# 1       Income  0.028007

# %%
from sklearn import tree

# %%
tree.plot_tree(dt1,feature_names=x.columns, class_names=df['sales'].unique(), filled=True)
# Out:
# [Text(0.6929347826086957, 0.95, 'Price <= 139.331\nentropy = 1.0\nsamples = 280\nvalue = [137, 143]\nclass = Bad'),
#  Text(0.4945652173913043, 0.85, 'Age <= 66.989\nentropy = 0.988\nsamples = 243\nvalue = [106, 137]\nclass = Bad'),
#  Text(0.2826086956521739, 0.75, 'Advertising <= 3.468\nentropy = 0.946\nsamples = 181\nvalue = [66, 115]\nclass = Bad'),
#  Text(0.08152173913043478, 0.65, 'Price <= 56.65\nentropy = 0.998\nsamples = 82\nvalue = [39, 43]\nclass = Bad'),
#  Text(0.059782608695652176, 0.55, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Bad'),
#  Text(0.10326086956521739, 0.55, 'Price <= 91.131\nentropy = 1.0\nsamples = 78\nvalue = [39, 39]\nclass = Good'),
#  Text(0.043478260869565216, 0.45, 'Price <= 85.895\nentropy = 0.371\nsamples = 14\nvalue = [1, 13]\nclass = Bad'),
#  Text(0.021739130434782608, 0.35, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Bad'),
#  Text(0.06521739130434782, 0.35, 'entropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = Bad'),
#  Text(0.16304347826086957, 0.45, 'Advertising <= 0.031\nentropy = 0.974\nsamples = 64\nvalue = [38, 26]\nclass = Good'),
#  Text(0.10869565217391304, 0.35, 'ShelveLoc <= 0.344\nentropy = 0.925\nsamples = 50\nvalue = [33, 17]\nclass = Good'),
#  Text(0.06521739130434782, 0.25, 'Population <= 222.216\nentropy = 0.391\nsamples = 13\nvalue = [12, 1]\nclass = Good'),
#  Text(0.043478260869565216, 0.15, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Good'),
#  Text(0.08695652173913043, 0.15, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = Good'),
#  Text(0.15217391304347827, 0.25, 'ShelveLoc <= 1.735\nentropy = 0.987\nsamples = 37\nvalue = [21, 16]\nclass = Good'),
#  Text(0.13043478260869565, 0.15, 'entropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = Bad'),
#  Text(0.17391304347826086, 0.15, 'Price <= 134.372\nentropy = 0.918\nsamples = 30\nvalue = [20, 10]\nclass = Good'),
#  Text(0.15217391304347827, 0.05, 'entropy = 0.94\nsamples = 28\nvalue = [18, 10]\nclass = Good'),
#  Text(0.1956521739130435, 0.05, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Good'),
#  Text(0.21739130434782608, 0.35, 'Income <= 55.324\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]\nclass = Bad'),
#  Text(0.1956521739130435, 0.25, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = Good'),
#  Text(0.2391304347826087, 0.25, 'Income <= 75.164\nentropy = 0.722\nsamples = 10\nvalue = [2, 8]\nclass = Bad'),
#  Text(0.21739130434782608, 0.15, 'entropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = Bad'),
#  Text(0.2608695652173913, 0.15, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Bad'),
#  Text(0.483695652173913, 0.65, 'Price <= 126.07\nentropy = 0.845\nsamples = 99\nvalue = [27, 72]\nclass = Bad'),
#  Text(0.40217391304347827, 0.55, 'Advertising <= 13.997\nentropy = 0.661\nsamples = 70\nvalue = [12, 58]\nclass = Bad'),
#  Text(0.34782608695652173, 0.45, 'Advertising <= 7.016\nentropy = 0.794\nsamples = 46\nvalue = [11, 35]\nclass = Bad'),
#  Text(0.30434782608695654, 0.35, 'ShelveLoc <= 0.284\nentropy = 0.993\nsamples = 20\nvalue = [9, 11]\nclass = Bad'),
#  Text(0.2826086956521739, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Good'),
#  Text(0.32608695652173914, 0.25, 'Education <= 14.264\nentropy = 0.896\nsamples = 16\nvalue = [5, 11]\nclass = Bad'),
#  Text(0.30434782608695654, 0.15, 'Price <= 110.4\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]\nclass = Good'),
#  Text(0.2826086956521739, 0.05, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Bad'),
#  Text(0.32608695652173914, 0.05, 'entropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = Good'),
#  Text(0.34782608695652173, 0.15, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Bad'),
#  Text(0.391304347826087, 0.35, 'Age <= 43.689\nentropy = 0.391\nsamples = 26\nvalue = [2, 24]\nclass = Bad'),
#  Text(0.3695652173913043, 0.25, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Bad'),
#  Text(0.41304347826086957, 0.25, 'Population <= 192.409\nentropy = 0.544\nsamples = 16\nvalue = [2, 14]\nclass = Bad'),
#  Text(0.391304347826087, 0.15, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Bad'),
#  Text(0.43478260869565216, 0.15, 'Price <= 94.566\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]\nclass = Bad'),
#  Text(0.41304347826086957, 0.05, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Bad'),
#  Text(0.45652173913043476, 0.05, 'entropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = Bad'),
#  Text(0.45652173913043476, 0.45, 'CompPrice <= 97.461\nentropy = 0.25\nsamples = 24\nvalue = [1, 23]\nclass = Bad'),
#  Text(0.43478260869565216, 0.35, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Good'),
#  Text(0.4782608695652174, 0.35, 'entropy = 0.0\nsamples = 22\nvalue = [0, 22]\nclass = Bad'),
#  Text(0.5652173913043478, 0.55, 'Advertising <= 24.861\nentropy = 0.999\nsamples = 29\nvalue = [15, 14]\nclass = Good'),
#  Text(0.5434782608695652, 0.45, 'ShelveLoc <= 0.454\nentropy = 0.996\nsamples = 28\nvalue = [15, 13]\nclass = Good'),
#  Text(0.5217391304347826, 0.35, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Good'),
#  Text(0.5652173913043478, 0.35, 'ShelveLoc <= 1.887\nentropy = 0.976\nsamples = 22\nvalue = [9, 13]\nclass = Bad'),
#  Text(0.5434782608695652, 0.25, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Bad'),
#  Text(0.5869565217391305, 0.25, 'Age <= 38.244\nentropy = 0.94\nsamples = 14\nvalue = [9, 5]\nclass = Good'),
#  Text(0.5652173913043478, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Bad'),
#  Text(0.6086956521739131, 0.15, 'CompPrice <= 128.127\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]\nclass = Good'),
#  Text(0.5869565217391305, 0.05, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Good'),
#  Text(0.6304347826086957, 0.05, 'entropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = Bad'),
#  Text(0.5869565217391305, 0.45, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Bad'),
#  Text(0.7065217391304348, 0.75, 'US <= 0.827\nentropy = 0.938\nsamples = 62\nvalue = [40, 22]\nclass = Good'),
#  Text(0.6304347826086957, 0.65, 'Urban <= 0.646\nentropy = 0.559\nsamples = 23\nvalue = [20, 3]\nclass = Good'),
#  Text(0.6086956521739131, 0.55, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Good'),
#  Text(0.6521739130434783, 0.55, 'ShelveLoc <= 0.042\nentropy = 0.75\nsamples = 14\nvalue = [11, 3]\nclass = Good'),
#  Text(0.6304347826086957, 0.45, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Good'),
#  Text(0.6739130434782609, 0.45, 'Population <= 322.081\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]\nclass = Good'),
#  Text(0.6521739130434783, 0.35, 'Population <= 137.504\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = Good'),
#  Text(0.6304347826086957, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Good'),
#  Text(0.6739130434782609, 0.25, 'entropy = 1.0\nsamples = 6\nvalue = [3, 3]\nclass = Good'),
#  Text(0.6956521739130435, 0.35, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Good'),
#  Text(0.782608695652174, 0.65, 'Price <= 93.105\nentropy = 1.0\nsamples = 39\nvalue = [20, 19]\nclass = Good'),
#  Text(0.7391304347826086, 0.55, 'Urban <= 0.584\nentropy = 0.722\nsamples = 10\nvalue = [2, 8]\nclass = Bad'),
#  Text(0.717391304347826, 0.45, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Good'),
#  Text(0.7608695652173914, 0.45, 'Age <= 77.379\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = Bad'),
#  Text(0.7391304347826086, 0.35, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Bad'),
#  Text(0.782608695652174, 0.35, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Good'),
#  Text(0.8260869565217391, 0.55, 'ShelveLoc <= 0.974\nentropy = 0.958\nsamples = 29\nvalue = [18, 11]\nclass = Good'),
#  Text(0.8043478260869565, 0.45, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Good'),
#  Text(0.8478260869565217, 0.45, 'ShelveLoc <= 1.133\nentropy = 0.993\nsamples = 20\nvalue = [9, 11]\nclass = Bad'),
#  Text(0.8260869565217391, 0.35, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Bad'),
#  Text(0.8695652173913043, 0.35, 'Education <= 14.282\nentropy = 0.989\nsamples = 16\nvalue = [9, 7]\nclass = Good'),
#  Text(0.8478260869565217, 0.25, 'Price <= 126.373\nentropy = 0.994\nsamples = 11\nvalue = [5, 6]\nclass = Bad'),
#  Text(0.8260869565217391, 0.15, 'Urban <= 0.692\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]\nclass = Bad'),
#  Text(0.8043478260869565, 0.05, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Bad'),
#  Text(0.8478260869565217, 0.05, 'entropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = Good'),
#  Text(0.8695652173913043, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Good'),
#  Text(0.8913043478260869, 0.25, 'entropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = Good'),
#  Text(0.8913043478260869, 0.85, 'Population <= 104.893\nentropy = 0.639\nsamples = 37\nvalue = [31, 6]\nclass = Good'),
#  Text(0.8478260869565217, 0.75, 'Advertising <= 3.112\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = Good'),
#  Text(0.8260869565217391, 0.65, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Bad'),
#  Text(0.8695652173913043, 0.65, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Good'),
#  Text(0.9347826086956522, 0.75, 'Urban <= 0.371\nentropy = 0.48\nsamples = 29\nvalue = [26, 3]\nclass = Good'),
#  Text(0.9130434782608695, 0.65, 'entropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = Good'),
#  Text(0.9565217391304348, 0.65, 'Population <= 413.187\nentropy = 0.267\nsamples = 22\nvalue = [21, 1]\nclass = Good'),
#  Text(0.9347826086956522, 0.55, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = Good'),
#  Text(0.9782608695652174, 0.55, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = Good')]
